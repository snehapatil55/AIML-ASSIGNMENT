# %% [markdown]
# # Assignment 5:(24/02/2026)
#
# ## Assignment Name: Dataset Detective
#
# ## Description
# Load a dataset, display top rows, find highest value column, count missing values, and share insights.

# %%
import pandas as pd

# Load dataset from internet
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")

print("Top 5 Rows:")
print(df.head())

# Find highest value column
max_values = df.max(numeric_only=True)
highest_column = max_values.idxmax()

print("\nColumn with highest value:", highest_column)
print("Highest value:", max_values.max())

# Missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Top 5 Rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Column with highest value: sepal_length
# Highest value: 7.9
#
# Missing Values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
